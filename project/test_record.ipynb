# %% [markdown]
# ### Detect & Segment 성능 비교

# %% [markdown]
# #### Detect

# %% [markdown]
# firesmoke_train
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Segment

# %% [markdown]
# firesmoke_seg_train
#
# ![image.png](attachment:image.png)
