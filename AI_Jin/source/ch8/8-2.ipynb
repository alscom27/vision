# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.cifar10.load_data()

n_class=10			# 부류 수
img_siz=(32,32,3)
img_expanded_siz=(72,72,3)

patch_siz=6			# 패치 크기
p2=(img_expanded_siz[0]//patch_siz)**2 # 패치 개수
d_model=64			# 임베딩 벡터 차원
h=8				# 헤드 개수
N=6				# 인코더 블록의 개수
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 16s 0us/step

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.p_siz=patch_size

    def call(self, img):
        batch_size=tf.shape(img)[0]
        patches=tf.image.extract_patches(images=img,sizes=[1,self.p_siz,self.p_siz,1],strides=[1,self.p_siz,self.p_siz,1],rates=[1,1,1,1],padding="VALID")
        patch_dims=patches.shape[-1]
        patches=tf.reshape(patches,[batch_size,-1,patch_dims])
        return patches

class PatchEncoder(layers.Layer):
    def __init__(self,p2,d_model): # p2: 패치 개수
        super(PatchEncoder,self).__init__()
        self.p2=p2
        self.projection=layers.Dense(units=d_model)
        self.position_embedding=layers.Embedding(input_dim=p2,output_dim=d_model)

    def call(self,patch):
        positions=tf.range(start=0,limit=self.p2,delta=1)
        encoded=self.projection(patch)+self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    input=layers.Input(shape=(img_siz))
    nor=layers.Normalization()(input)
    exp=layers.Resizing(img_expanded_siz[0],img_expanded_siz[1])(nor)

    x=layers.RandomFlip('horizontal')(exp)
    x=layers.RandomRotation(factor=0.02)(x)
    x=layers.RandomZoom(height_factor=0.2, width_factor=0.2)(x)

    patches=Patches(patch_siz)(x)		# 패치 생성
    x=PatchEncoder(p2,d_model)(patches)	# 패치 인코딩

    for _ in range(N):			# 다중 인코더 블록
        x1=layers.LayerNormalization(epsilon=1e-6)(x)		# 층 정규화
        x2=layers.MultiHeadAttention(num_heads=h,key_dim=d_model//h,dropout=0.1)(x1,x1)			# MHA
        x3=layers.Add()([x2,x])		# 지름길 연결
        x4=layers.LayerNormalization(epsilon=1e-6)(x3)	# 층 정규화
        x5=layers.Dense(d_model*2,activation=tf.nn.gelu)(x4)
        x6=layers.Dropout(0.1)(x5)
        x7=layers.Dense(d_model,activation=tf.nn.gelu)(x6)
        x8=layers.Dropout(0.1)(x7)
        x=layers.Add()([x8,x3])		# 지름길 연결

        x=layers.LayerNormalization(epsilon=1e-6)(x)
        x=layers.Flatten()(x)
        x=layers.Dropout(0.5)(x)
        x=layers.Dense(2048,activation=tf.nn.gelu)(x)
        x=layers.Dropout(0.5)(x)
        x=layers.Dense(1024,activation=tf.nn.gelu)(x)
        x=layers.Dropout(0.5)(x)
        output=layers.Dense(n_class,activation='softmax')(x)

        model=keras.Model(inputs=input,outputs=output)
        return model

# %%
model=create_vit_classifier()
model.layers[1].adapt(x_train)

model.compile(optimizer=Adam(),loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
hist=model.fit(x_train,y_train,batch_size=128,epochs=100,validation_data=(x_test,y_test),verbose=1)

res=model.evaluate(x_test,y_test,verbose=0)
print('정확률=',res[1]*100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:708: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.2701 - loss: 2.5185 - val_accuracy: 0.4901 - val_loss: 1.4320
# Epoch 2/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.4353 - loss: 1.5727 - val_accuracy: 0.5409 - val_loss: 1.2766
# Epoch 3/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.4920 - loss: 1.4190 - val_accuracy: 0.5824 - val_loss: 1.1762
# Epoch 4/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.5160 - loss: 1.3580 - val_accuracy: 0.5978 - val_loss: 1.1226
# Epoch 5/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.5374 - loss: 1.2971 - val_accuracy: 0.6263 - val_loss: 1.0695
# Epoch 6/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.5616 - loss: 1.2392 - val_accuracy: 0.6287 - val_loss: 1.0639
# Epoch 7/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.5821 - loss: 1.1861 - val_accuracy: 0.6522 - val_loss: 0.9793
# Epoch 8/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.5998 - loss: 1.1465 - val_accuracy: 0.6684 - val_loss: 0.9446
# Epoch 9/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.6155 - loss: 1.0945 - val_accuracy: 0.6757 - val_loss: 0.9386
# Epoch 10/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.6236 - loss: 1.0777 - val_accuracy: 0.6973 - val_loss: 0.8826
# Epoch 11/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.6301 - loss: 1.0529 - val_accuracy: 0.6992 - val_loss: 0.8609
# Epoch 12/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.6491 - loss: 1.0056 - val_accuracy: 0.6991 - val_loss: 0.8669
# Epoch 13/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.6568 - loss: 0.9827 - val_accuracy: 0.7129 - val_loss: 0.8366
# Epoch 14/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.6683 - loss: 0.9591 - val_accuracy: 0.7176 - val_loss: 0.8138
# Epoch 15/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.6698 - loss: 0.9419 - val_accuracy: 0.7221 - val_loss: 0.8021
# Epoch 16/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.6811 - loss: 0.9200 - val_accuracy: 0.7286 - val_loss: 0.8042
# Epoch 17/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.6913 - loss: 0.8888 - val_accuracy: 0.7327 - val_loss: 0.7560
# Epoch 18/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.7006 - loss: 0.8628 - val_accuracy: 0.7325 - val_loss: 0.7672
# Epoch 19/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.6983 - loss: 0.8531 - val_accuracy: 0.7203 - val_loss: 0.7976
# Epoch 20/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7100 - loss: 0.8380 - val_accuracy: 0.7530 - val_loss: 0.7068
# Epoch 21/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.7132 - loss: 0.8211 - val_accuracy: 0.7591 - val_loss: 0.6990
# Epoch 22/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7245 - loss: 0.7874 - val_accuracy: 0.7535 - val_loss: 0.7144
# Epoch 23/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7248 - loss: 0.7887 - val_accuracy: 0.7611 - val_loss: 0.6792
# Epoch 24/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.7289 - loss: 0.7780 - val_accuracy: 0.7628 - val_loss: 0.6900
# Epoch 25/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.7362 - loss: 0.7601 - val_accuracy: 0.7689 - val_loss: 0.6663
# Epoch 26/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.7382 - loss: 0.7511 - val_accuracy: 0.7711 - val_loss: 0.6686
# Epoch 27/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.7449 - loss: 0.7289 - val_accuracy: 0.7706 - val_loss: 0.6669
# Epoch 28/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.7508 - loss: 0.7151 - val_accuracy: 0.7638 - val_loss: 0.6896
# Epoch 29/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7494 - loss: 0.7127 - val_accuracy: 0.7758 - val_loss: 0.6429
# Epoch 30/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.7566 - loss: 0.6949 - val_accuracy: 0.7806 - val_loss: 0.6430
# Epoch 31/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.7608 - loss: 0.6817 - val_accuracy: 0.7673 - val_loss: 0.6694
# Epoch 32/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.7655 - loss: 0.6712 - val_accuracy: 0.7799 - val_loss: 0.6367
# Epoch 33/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.7657 - loss: 0.6671 - val_accuracy: 0.7765 - val_loss: 0.6422
# Epoch 34/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7726 - loss: 0.6525 - val_accuracy: 0.7778 - val_loss: 0.6404
# Epoch 35/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.7796 - loss: 0.6297 - val_accuracy: 0.7897 - val_loss: 0.6099
# Epoch 36/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.7787 - loss: 0.6339 - val_accuracy: 0.7822 - val_loss: 0.6305
# Epoch 37/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7813 - loss: 0.6274 - val_accuracy: 0.7781 - val_loss: 0.6461
# Epoch 38/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.7834 - loss: 0.6154 - val_accuracy: 0.7827 - val_loss: 0.6183
# Epoch 39/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.7880 - loss: 0.5990 - val_accuracy: 0.7853 - val_loss: 0.6268
# Epoch 40/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7934 - loss: 0.5907 - val_accuracy: 0.7868 - val_loss: 0.6262
# Epoch 41/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.7952 - loss: 0.5944 - val_accuracy: 0.7848 - val_loss: 0.6146
# Epoch 42/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7966 - loss: 0.5838 - val_accuracy: 0.7995 - val_loss: 0.5971
# Epoch 43/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.8013 - loss: 0.5781 - val_accuracy: 0.7955 - val_loss: 0.5936
# Epoch 44/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8014 - loss: 0.5715 - val_accuracy: 0.7977 - val_loss: 0.5946
# Epoch 45/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8051 - loss: 0.5587 - val_accuracy: 0.7927 - val_loss: 0.6100
# Epoch 46/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.8129 - loss: 0.5431 - val_accuracy: 0.7998 - val_loss: 0.5923
# Epoch 47/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.8135 - loss: 0.5405 - val_accuracy: 0.7889 - val_loss: 0.6295
# Epoch 48/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8109 - loss: 0.5412 - val_accuracy: 0.8032 - val_loss: 0.5806
# Epoch 49/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8162 - loss: 0.5256 - val_accuracy: 0.7972 - val_loss: 0.6060
# Epoch 50/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.8142 - loss: 0.5308 - val_accuracy: 0.7954 - val_loss: 0.6189
# Epoch 51/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8161 - loss: 0.5250 - val_accuracy: 0.8012 - val_loss: 0.5916
# Epoch 52/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8243 - loss: 0.5114 - val_accuracy: 0.7975 - val_loss: 0.6035
# Epoch 53/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8246 - loss: 0.5046 - val_accuracy: 0.8044 - val_loss: 0.5819
# Epoch 54/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8259 - loss: 0.5028 - val_accuracy: 0.8042 - val_loss: 0.5840
# Epoch 55/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8332 - loss: 0.4793 - val_accuracy: 0.8017 - val_loss: 0.5942
# Epoch 56/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8312 - loss: 0.4848 - val_accuracy: 0.8069 - val_loss: 0.5871
# Epoch 57/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8327 - loss: 0.4843 - val_accuracy: 0.8071 - val_loss: 0.5811
# Epoch 58/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8346 - loss: 0.4763 - val_accuracy: 0.8112 - val_loss: 0.5713
# Epoch 59/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8415 - loss: 0.4566 - val_accuracy: 0.7960 - val_loss: 0.6195
# Epoch 60/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8361 - loss: 0.4741 - val_accuracy: 0.8046 - val_loss: 0.6005
# Epoch 61/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8374 - loss: 0.4691 - val_accuracy: 0.8099 - val_loss: 0.5676
# Epoch 62/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8400 - loss: 0.4562 - val_accuracy: 0.8150 - val_loss: 0.5681
# Epoch 63/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8402 - loss: 0.4543 - val_accuracy: 0.8097 - val_loss: 0.5745
# Epoch 64/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8441 - loss: 0.4523 - val_accuracy: 0.8149 - val_loss: 0.5725
# Epoch 65/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8428 - loss: 0.4540 - val_accuracy: 0.8166 - val_loss: 0.5618
# Epoch 66/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 52ms/step - accuracy: 0.8449 - loss: 0.4458 - val_accuracy: 0.8171 - val_loss: 0.5503
# Epoch 67/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8486 - loss: 0.4356 - val_accuracy: 0.8111 - val_loss: 0.5702
# Epoch 68/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8514 - loss: 0.4293 - val_accuracy: 0.8073 - val_loss: 0.5914
# Epoch 69/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8523 - loss: 0.4259 - val_accuracy: 0.8079 - val_loss: 0.5873
# Epoch 70/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8541 - loss: 0.4236 - val_accuracy: 0.8108 - val_loss: 0.5936
# Epoch 71/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8547 - loss: 0.4198 - val_accuracy: 0.8218 - val_loss: 0.5528
# Epoch 72/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8569 - loss: 0.4110 - val_accuracy: 0.8077 - val_loss: 0.5926
# Epoch 73/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8559 - loss: 0.4175 - val_accuracy: 0.8173 - val_loss: 0.5694
# Epoch 74/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8557 - loss: 0.4078 - val_accuracy: 0.8198 - val_loss: 0.5603
# Epoch 75/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8563 - loss: 0.4161 - val_accuracy: 0.8128 - val_loss: 0.5754
# Epoch 76/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8556 - loss: 0.4156 - val_accuracy: 0.7963 - val_loss: 0.6522
# Epoch 77/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8633 - loss: 0.3960 - val_accuracy: 0.8120 - val_loss: 0.5792
# Epoch 78/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8608 - loss: 0.4001 - val_accuracy: 0.8196 - val_loss: 0.5625
# Epoch 79/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.8645 - loss: 0.3971 - val_accuracy: 0.8198 - val_loss: 0.5668
# Epoch 80/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8663 - loss: 0.3896 - val_accuracy: 0.8222 - val_loss: 0.5526
# Epoch 81/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8663 - loss: 0.3836 - val_accuracy: 0.8228 - val_loss: 0.5522
# Epoch 82/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8646 - loss: 0.3864 - val_accuracy: 0.8228 - val_loss: 0.5673
# Epoch 83/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8667 - loss: 0.3848 - val_accuracy: 0.8112 - val_loss: 0.5826
# Epoch 84/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8650 - loss: 0.3880 - val_accuracy: 0.8113 - val_loss: 0.5836
# Epoch 85/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8706 - loss: 0.3780 - val_accuracy: 0.8118 - val_loss: 0.5936
# Epoch 86/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8739 - loss: 0.3688 - val_accuracy: 0.8206 - val_loss: 0.5408
# Epoch 87/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8739 - loss: 0.3727 - val_accuracy: 0.8217 - val_loss: 0.5578
# Epoch 88/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8726 - loss: 0.3644 - val_accuracy: 0.8221 - val_loss: 0.5622
# Epoch 89/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8723 - loss: 0.3683 - val_accuracy: 0.8203 - val_loss: 0.5768
# Epoch 90/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8760 - loss: 0.3622 - val_accuracy: 0.8111 - val_loss: 0.5979
# Epoch 91/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8770 - loss: 0.3621 - val_accuracy: 0.8247 - val_loss: 0.5673
# Epoch 92/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8756 - loss: 0.3585 - val_accuracy: 0.8179 - val_loss: 0.5738
# Epoch 93/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8784 - loss: 0.3538 - val_accuracy: 0.8224 - val_loss: 0.5714
# Epoch 94/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8780 - loss: 0.3550 - val_accuracy: 0.8247 - val_loss: 0.5610
# Epoch 95/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8816 - loss: 0.3485 - val_accuracy: 0.8191 - val_loss: 0.5924
# Epoch 96/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8830 - loss: 0.3445 - val_accuracy: 0.8233 - val_loss: 0.5647
# Epoch 97/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.8807 - loss: 0.3467 - val_accuracy: 0.8226 - val_loss: 0.5557
# Epoch 98/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8814 - loss: 0.3484 - val_accuracy: 0.8270 - val_loss: 0.5485
# Epoch 99/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8830 - loss: 0.3442 - val_accuracy: 0.8235 - val_loss: 0.5502
# Epoch 100/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.8847 - loss: 0.3348 - val_accuracy: 0.8220 - val_loss: 0.5881
# 정확률= 82.20000267028809

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.grid()
plt.show()
